# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
people_path = '/content/drive/MyDrive/B.Tech/kaggle/predicting-red-hat-business-value/people.csv'
act_test_path = '/content/drive/MyDrive/B.Tech/kaggle/predicting-red-hat-business-value/act_test.csv'

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import joblib

# %%
df_people = pd.read_csv(people_path)
df_test = pd.read_csv(act_test_path)

# %%
df_null = pd.DataFrame(df_test.isnull().sum(), columns=['Null count'])
df_null['Null %'] = (df_null['Null count']/df_test.shape[0])*100
df_null
# Out:
#                    Null count     Null %
# people_id                   0   0.000000
# activity_id                 0   0.000000
# date                        0   0.000000
# activity_category           0   0.000000
# char_1                 458595  91.960488
# char_2                 458595  91.960488
# char_3                 458595  91.960488
# char_4                 458595  91.960488
# char_5                 458595  91.960488
# char_6                 458595  91.960488
# char_7                 458595  91.960488
# char_8                 458595  91.960488
# char_9                 458595  91.960488
# char_10                 40092   8.039512

# %%
df_test1 = df_test.drop(['char_1', 'char_2', 'char_3', 'char_4', 'char_5', 'char_6',
                           'char_7', 'char_8', 'char_9'], axis = 1)
df_test1
# Out:
#          people_id   activity_id        date activity_category    char_10
# 0       ppl_100004   act1_249281  2022-07-20            type 1        NaN
# 1       ppl_100004   act2_230855  2022-07-20            type 5   type 682
# 2        ppl_10001   act1_240724  2022-10-14            type 1        NaN
# 3        ppl_10001    act1_83552  2022-11-27            type 1        NaN
# 4        ppl_10001  act2_1043301  2022-10-15            type 5  type 3015
# ...            ...           ...         ...               ...        ...
# 498682   ppl_99997  act2_4367092  2023-04-22            type 2     type 1
# 498683   ppl_99997  act2_4404220  2022-11-12            type 2     type 1
# 498684   ppl_99997   act2_448830  2022-08-02            type 2     type 1
# 498685   ppl_99997   act2_450133  2022-08-02            type 2     type 1
# 498686   ppl_99997   act2_847967  2022-10-15            type 2     type 1
#
# [498687 rows x 5 columns]

# %%
df_test1.isnull().sum()
# Out:
# people_id                0
# activity_id              0
# date                     0
# activity_category        0
# char_10              40092
# dtype: int64

# %%
def convert_str_to_num(x):
    t = x.split(' ')
    return int(t[1])

# %%
act_char = ['activity_category']
for i in act_char:
    df_test1[i] = df_test1[i].apply(convert_str_to_num)
df_test1
# Out:
#          people_id   activity_id        date  activity_category    char_10
# 0       ppl_100004   act1_249281  2022-07-20                  1        NaN
# 1       ppl_100004   act2_230855  2022-07-20                  5   type 682
# 2        ppl_10001   act1_240724  2022-10-14                  1        NaN
# 3        ppl_10001    act1_83552  2022-11-27                  1        NaN
# 4        ppl_10001  act2_1043301  2022-10-15                  5  type 3015
# ...            ...           ...         ...                ...        ...
# 498682   ppl_99997  act2_4367092  2023-04-22                  2     type 1
# 498683   ppl_99997  act2_4404220  2022-11-12                  2     type 1
# 498684   ppl_99997   act2_448830  2022-08-02                  2     type 1
# 498685   ppl_99997   act2_450133  2022-08-02                  2     type 1
# 498686   ppl_99997   act2_847967  2022-10-15                  2     type 1
#
# [498687 rows x 5 columns]

# %%
df_test1.rename(columns = {"char_10": "activity_char"}, inplace = True)
df_test1
# Out:
#          people_id   activity_id        date  activity_category activity_char
# 0       ppl_100004   act1_249281  2022-07-20                  1           NaN
# 1       ppl_100004   act2_230855  2022-07-20                  5      type 682
# 2        ppl_10001   act1_240724  2022-10-14                  1           NaN
# 3        ppl_10001    act1_83552  2022-11-27                  1           NaN
# 4        ppl_10001  act2_1043301  2022-10-15                  5     type 3015
# ...            ...           ...         ...                ...           ...
# 498682   ppl_99997  act2_4367092  2023-04-22                  2        type 1
# 498683   ppl_99997  act2_4404220  2022-11-12                  2        type 1
# 498684   ppl_99997   act2_448830  2022-08-02                  2        type 1
# 498685   ppl_99997   act2_450133  2022-08-02                  2        type 1
# 498686   ppl_99997   act2_847967  2022-10-15                  2        type 1
#
# [498687 rows x 5 columns]

# %%
df_test2 = pd.merge(df_test1, df_people, how = 'left', on = ['people_id'])
df_test2
# Out:
#          people_id   activity_id      date_x  ...  char_36 char_37 char_38
# 0       ppl_100004   act1_249281  2022-07-20  ...     True    True      76
# 1       ppl_100004   act2_230855  2022-07-20  ...     True    True      76
# 2        ppl_10001   act1_240724  2022-10-14  ...     True    True      90
# 3        ppl_10001    act1_83552  2022-11-27  ...     True    True      90
# 4        ppl_10001  act2_1043301  2022-10-15  ...     True    True      90
# ...            ...           ...         ...  ...      ...     ...     ...
# 498682   ppl_99997  act2_4367092  2023-04-22  ...    False   False      36
# 498683   ppl_99997  act2_4404220  2022-11-12  ...    False   False      36
# 498684   ppl_99997   act2_448830  2022-08-02  ...    False   False      36
# 498685   ppl_99997   act2_450133  2022-08-02  ...    False   False      36
# 498686   ppl_99997   act2_847967  2022-10-15  ...    False   False      36
#
# [498687 rows x 45 columns]

# %%
df_test2['date_x'] = pd.to_datetime(df_test2['date_x'])
df_test2['date_y'] = pd.to_datetime(df_test2['date_y'])

print(type(df_test2['date_x'][0]))
print(type(df_test2['date_y'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df_test2['days_difference'] = (df_test2['date_x'] - df_test2['date_y']).apply(lambda x: x.days)
df_test2
# Out:
#          people_id   activity_id     date_x  ...  char_37 char_38 days_difference
# 0       ppl_100004   act1_249281 2022-07-20  ...     True      76               0
# 1       ppl_100004   act2_230855 2022-07-20  ...     True      76               0
# 2        ppl_10001   act1_240724 2022-10-14  ...     True      90               0
# 3        ppl_10001    act1_83552 2022-11-27  ...     True      90              44
# 4        ppl_10001  act2_1043301 2022-10-15  ...     True      90               1
# ...            ...           ...        ...  ...      ...     ...             ...
# 498682   ppl_99997  act2_4367092 2023-04-22  ...    False      36             406
# 498683   ppl_99997  act2_4404220 2022-11-12  ...    False      36             245
# 498684   ppl_99997   act2_448830 2022-08-02  ...    False      36             143
# 498685   ppl_99997   act2_450133 2022-08-02  ...    False      36             143
# 498686   ppl_99997   act2_847967 2022-10-15  ...    False      36             217
#
# [498687 rows x 46 columns]

# %%
type(df_test2['days_difference'][0])
# Out:
# numpy.int64

# %%
df_test2.dtypes
# Out:
# people_id                    object
# activity_id                  object
# date_x               datetime64[ns]
# activity_category             int64
# activity_char                object
# char_1                       object
# group_1                      object
# char_2                       object
# date_y               datetime64[ns]
# char_3                       object
# char_4                       object
# char_5                       object
# char_6                       object
# char_7                       object
# char_8                       object
# char_9                       object
# char_10                        bool
# char_11                        bool
# char_12                        bool
# char_13                        bool
# char_14                        bool
# char_15                        bool
# char_16                        bool
# char_17                        bool
# char_18                        bool
# char_19                        bool
# char_20                        bool
# char_21                        bool
# char_22                        bool
# char_23                        bool
# char_24                        bool
# char_25                        bool
# char_26                        bool
# char_27                        bool
# char_28                        bool
# char_29                        bool
# char_30                        bool
# char_31                        bool
# char_32                        bool
# char_33                        bool
# char_34                        bool
# char_35                        bool
# char_36                        bool
# char_37                        bool
# char_38                       int64
# days_difference               int64
# dtype: object

# %%
df_test3 = df_test2.copy()
for i in df_test3.any(bool_only = True).index:
    df_test3[i] = df_test3[i].astype(int)
df_test3
# Out:
#          people_id   activity_id     date_x  ...  char_37 char_38 days_difference
# 0       ppl_100004   act1_249281 2022-07-20  ...        1      76               0
# 1       ppl_100004   act2_230855 2022-07-20  ...        1      76               0
# 2        ppl_10001   act1_240724 2022-10-14  ...        1      90               0
# 3        ppl_10001    act1_83552 2022-11-27  ...        1      90              44
# 4        ppl_10001  act2_1043301 2022-10-15  ...        1      90               1
# ...            ...           ...        ...  ...      ...     ...             ...
# 498682   ppl_99997  act2_4367092 2023-04-22  ...        0      36             406
# 498683   ppl_99997  act2_4404220 2022-11-12  ...        0      36             245
# 498684   ppl_99997   act2_448830 2022-08-02  ...        0      36             143
# 498685   ppl_99997   act2_450133 2022-08-02  ...        0      36             143
# 498686   ppl_99997   act2_847967 2022-10-15  ...        0      36             217
#
# [498687 rows x 46 columns]

# %%
df_test4 = df_test3.drop(['date_x', 'date_y'], axis = 1)
df_test4
# Out:
#          people_id   activity_id  ...  char_38 days_difference
# 0       ppl_100004   act1_249281  ...       76               0
# 1       ppl_100004   act2_230855  ...       76               0
# 2        ppl_10001   act1_240724  ...       90               0
# 3        ppl_10001    act1_83552  ...       90              44
# 4        ppl_10001  act2_1043301  ...       90               1
# ...            ...           ...  ...      ...             ...
# 498682   ppl_99997  act2_4367092  ...       36             406
# 498683   ppl_99997  act2_4404220  ...       36             245
# 498684   ppl_99997   act2_448830  ...       36             143
# 498685   ppl_99997   act2_450133  ...       36             143
# 498686   ppl_99997   act2_847967  ...       36             217
#
# [498687 rows x 44 columns]

# %%
chars = ['char_1','char_2','char_3','char_4','char_5','char_6','char_7','char_8','char_9', 'group_1']
for i in chars:
    df_test4[i] = df_test4[i].apply(convert_str_to_num)
df_test4
# Out:
#          people_id   activity_id  ...  char_38 days_difference
# 0       ppl_100004   act1_249281  ...       76               0
# 1       ppl_100004   act2_230855  ...       76               0
# 2        ppl_10001   act1_240724  ...       90               0
# 3        ppl_10001    act1_83552  ...       90              44
# 4        ppl_10001  act2_1043301  ...       90               1
# ...            ...           ...  ...      ...             ...
# 498682   ppl_99997  act2_4367092  ...       36             406
# 498683   ppl_99997  act2_4404220  ...       36             245
# 498684   ppl_99997   act2_448830  ...       36             143
# 498685   ppl_99997   act2_450133  ...       36             143
# 498686   ppl_99997   act2_847967  ...       36             217
#
# [498687 rows x 44 columns]

# %%
def convert_str_to_num_(x):
    t = x.split('_')
    return int(float(t[1]))

df_test4['people_id'] = df_test4['people_id'].apply(convert_str_to_num_)

df_test5 = df_test4.copy()

def convert_activity_id_1(x):
    t = x.split('_')
    return int(float(t[0][-1]))

def convert_activity_id_2(x):
    t = x.split('_')
    return int(float(t[1]))

df_test5['activity_id_act'] = df_test5['activity_id'].apply(convert_activity_id_1)
df_test5['activity_id'] = df_test5['activity_id'].apply(convert_activity_id_2)
df_test5
# Out:
#         people_id  activity_id  ...  days_difference activity_id_act
# 0          100004       249281  ...                0               1
# 1          100004       230855  ...                0               2
# 2           10001       240724  ...                0               1
# 3           10001        83552  ...               44               1
# 4           10001      1043301  ...                1               2
# ...           ...          ...  ...              ...             ...
# 498682      99997      4367092  ...              406               2
# 498683      99997      4404220  ...              245               2
# 498684      99997       448830  ...              143               2
# 498685      99997       450133  ...              143               2
# 498686      99997       847967  ...              217               2
#
# [498687 rows x 45 columns]

# %%
df_test5 = df_test5.fillna(0)

def convert_str_to_num_ac(x):
    if x == 0:
        return x
    else:
        t = x.split(' ')
        return int(t[1])

df_test5['activity_char'] = df_test5['activity_char'].apply(convert_str_to_num_ac)
df_test5
# Out:
#         people_id  activity_id  ...  days_difference  activity_id_act
# 0          100004       249281  ...                0                1
# 1          100004       230855  ...                0                2
# 2           10001       240724  ...                0                1
# 3           10001        83552  ...               44                1
# 4           10001      1043301  ...                1                2
# ...           ...          ...  ...              ...              ...
# 498682      99997      4367092  ...              406                2
# 498683      99997      4404220  ...              245                2
# 498684      99997       448830  ...              143                2
# 498685      99997       450133  ...              143                2
# 498686      99997       847967  ...              217                2
#
# [498687 rows x 45 columns]

# %%
df_test5.dtypes
# Out:
# people_id            int64
# activity_id          int64
# activity_category    int64
# activity_char        int64
# char_1               int64
# group_1              int64
# char_2               int64
# char_3               int64
# char_4               int64
# char_5               int64
# char_6               int64
# char_7               int64
# char_8               int64
# char_9               int64
# char_10              int64
# char_11              int64
# char_12              int64
# char_13              int64
# char_14              int64
# char_15              int64
# char_16              int64
# char_17              int64
# char_18              int64
# char_19              int64
# char_20              int64
# char_21              int64
# char_22              int64
# char_23              int64
# char_24              int64
# char_25              int64
# char_26              int64
# char_27              int64
# char_28              int64
# char_29              int64
# char_30              int64
# char_31              int64
# char_32              int64
# char_33              int64
# char_34              int64
# char_35              int64
# char_36              int64
# char_37              int64
# char_38              int64
# days_difference      int64
# activity_id_act      int64
# dtype: object

# %%
x_test = df_test5

model_rfc = joblib.load("/content/drive/MyDrive/B.Tech/kaggle/predicting-red-hat-business-value/model_rfc.joblib")

y_pred = model_rfc.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
output_rfc = pd.DataFrame({'activity_id': df_test['activity_id'], 'outcome': y_pred})
output_rfc
# Out:
#          activity_id  outcome
# 0        act1_249281        1
# 1        act2_230855        0
# 2        act1_240724        1
# 3         act1_83552        1
# 4       act2_1043301        1
# ...              ...      ...
# 498682  act2_4367092        0
# 498683  act2_4404220        0
# 498684   act2_448830        0
# 498685   act2_450133        0
# 498686   act2_847967        0
#
# [498687 rows x 2 columns]

# %%
output_rfc.to_csv('/content/drive/MyDrive/B.Tech/kaggle/predicting-red-hat-business-value/my_submission.csv', index=False)

# %%
df_test4
# Out:
#         people_id   activity_id  ...  char_38 days_difference
# 0          100004   act1_249281  ...       76               0
# 1          100004   act2_230855  ...       76               0
# 2           10001   act1_240724  ...       90               0
# 3           10001    act1_83552  ...       90              44
# 4           10001  act2_1043301  ...       90               1
# ...           ...           ...  ...      ...             ...
# 498682      99997  act2_4367092  ...       36             406
# 498683      99997  act2_4404220  ...       36             245
# 498684      99997   act2_448830  ...       36             143
# 498685      99997   act2_450133  ...       36             143
# 498686      99997   act2_847967  ...       36             217
#
# [498687 rows x 44 columns]

# %%
is_NaN = df_test4.isnull()
row_has_NaN = is_NaN.any(axis=1)
df_test5_null = df_test4[row_has_NaN].reset_index()
null_index = np.array(df_test5_null['index'])
df_test5_null = df_test5_null.drop(['index', 'activity_char'], axis=1)
activity_id_null = df_test5_null['activity_id']
df_test5_null['activity_id_act'] = df_test5_null['activity_id'].apply(convert_activity_id_1)
df_test5_null['activity_id'] = df_test5_null['activity_id'].apply(convert_activity_id_2)
df_test5_null
# Out:
#        people_id  activity_id  ...  days_difference  activity_id_act
# 0         100004       249281  ...                0                1
# 1          10001       240724  ...                0                1
# 2          10001        83552  ...               44                1
# 3         100010       218751  ...                0                1
# 4         100010       383524  ...                0                1
# ...          ...          ...  ...              ...              ...
# 40087      99881       250479  ...                1                1
# 40088      99899       412734  ...                0                1
# 40089      99934        85735  ...               86                1
# 40090      99956       352909  ...                1                1
# 40091      99975       187412  ...                0                1
#
# [40092 rows x 44 columns]

# %%
df_test5_non_null = df_test4.drop(labels=null_index, axis=0).reset_index()
non_null_index = np.array(df_test5_non_null['index'])
df_test5_non_null = df_test5_non_null.drop('index', axis=1)
df_test5_non_null['activity_char'] = df_test5_non_null['activity_char'].apply(convert_str_to_num)
activity_id_non_null = df_test5_non_null['activity_id']
df_test5_non_null['activity_id_act'] = df_test5_non_null['activity_id'].apply(convert_activity_id_1)
df_test5_non_null['activity_id'] = df_test5_non_null['activity_id'].apply(convert_activity_id_2)
df_test5_non_null
# Out:
#         people_id  activity_id  ...  days_difference  activity_id_act
# 0          100004       230855  ...                0                2
# 1           10001      1043301  ...                1                2
# 2           10001       112890  ...               44                2
# 3           10001      1169930  ...                1                2
# 4           10001      1924448  ...                1                2
# ...           ...          ...  ...              ...              ...
# 458590      99997      4367092  ...              406                2
# 458591      99997      4404220  ...              245                2
# 458592      99997       448830  ...              143                2
# 458593      99997       450133  ...              143                2
# 458594      99997       847967  ...              217                2
#
# [458595 rows x 45 columns]

# %% [markdown]
# ## For non_null dataframe

# %%
x_test = df_test5_non_null
x_test
# Out:
#         people_id  activity_id  ...  days_difference  activity_id_act
# 0          100004       230855  ...                0                2
# 1           10001      1043301  ...                1                2
# 2           10001       112890  ...               44                2
# 3           10001      1169930  ...                1                2
# 4           10001      1924448  ...                1                2
# ...           ...          ...  ...              ...              ...
# 458590      99997      4367092  ...              406                2
# 458591      99997      4404220  ...              245                2
# 458592      99997       448830  ...              143                2
# 458593      99997       450133  ...              143                2
# 458594      99997       847967  ...              217                2
#
# [458595 rows x 45 columns]

# %%
model_non_null = joblib.load("/content/drive/MyDrive/B.Tech/kaggle/predicting-red-hat-business-value/model_non_null.joblib")

# %%
y_pred = model_non_null.predict(x_test)
y_pred
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
df1 = pd.DataFrame({'index': non_null_index, 'activity_id': activity_id_non_null, 'outcome': y_pred})
df1
# Out:
#          index   activity_id  outcome
# 0            1   act2_230855        0
# 1            4  act2_1043301        1
# 2            5   act2_112890        1
# 3            6  act2_1169930        1
# 4            7  act2_1924448        1
# ...        ...           ...      ...
# 458590  498682  act2_4367092        0
# 458591  498683  act2_4404220        0
# 458592  498684   act2_448830        0
# 458593  498685   act2_450133        0
# 458594  498686   act2_847967        0
#
# [458595 rows x 3 columns]

# %% [markdown]
# ## For null dataframe

# %%
x_test = df_test5_null
x_test
# Out:
#        people_id  activity_id  ...  days_difference  activity_id_act
# 0         100004       249281  ...                0                1
# 1          10001       240724  ...                0                1
# 2          10001        83552  ...               44                1
# 3         100010       218751  ...                0                1
# 4         100010       383524  ...                0                1
# ...          ...          ...  ...              ...              ...
# 40087      99881       250479  ...                1                1
# 40088      99899       412734  ...                0                1
# 40089      99934        85735  ...               86                1
# 40090      99956       352909  ...                1                1
# 40091      99975       187412  ...                0                1
#
# [40092 rows x 44 columns]

# %%
model_null = joblib.load("/content/drive/MyDrive/B.Tech/kaggle/predicting-red-hat-business-value/model_null.joblib")

# %%
y_pred = model_null.predict(x_test)
y_pred
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
df2 = pd.DataFrame({'index': null_index, 'activity_id': activity_id_null, 'outcome': y_pred})
df2
# Out:
#         index  activity_id  outcome
# 0           0  act1_249281        0
# 1           2  act1_240724        1
# 2           3   act1_83552        1
# 3          27  act1_218751        0
# 4          28  act1_383524        0
# ...       ...          ...      ...
# 40087  498620  act1_250479        0
# 40088  498626  act1_412734        1
# 40089  498635   act1_85735        1
# 40090  498648  act1_352909        0
# 40091  498663  act1_187412        1
#
# [40092 rows x 3 columns]

# %%
output = pd.concat([df1, df2])
output = output.sort_values(by='index')
output = output.drop('index', axis=1)
output
# Out:
#          activity_id  outcome
# 0        act1_249281        0
# 0        act2_230855        0
# 1        act1_240724        1
# 2         act1_83552        1
# 1       act2_1043301        1
# ...              ...      ...
# 458590  act2_4367092        0
# 458591  act2_4404220        0
# 458592   act2_448830        0
# 458593   act2_450133        0
# 458594   act2_847967        0
#
# [498687 rows x 2 columns]

# %%
output.to_csv('/content/drive/MyDrive/B.Tech/kaggle/predicting-red-hat-business-value/my_submission_1.csv', index=False)
